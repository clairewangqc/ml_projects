# %%
from sklearn.datasets import load_boston
import pandas as pd
import numpy as np
import statsmodels.api as sm
import matplotlib.pyplot as plt
from statsmodels.sandbox.regression.predstd import wls_prediction_std
from vega_datasets import data
import seaborn as sns

# %%
housing_data =  pd.read_csv('https://raw.githubusercontent.com/cjflanagan/cs68/master/housing.csv')

# %%
# Data description available here: https://www.kaggle.com/c/house-prices-advanced-regression-techniques/data?select=data_description.txt
housing_data.head()
# Out:
#    Id  MSSubClass MSZoning  ...  SaleType  SaleCondition SalePrice
# 0   1          60       RL  ...        WD         Normal    208500
# 1   2          20       RL  ...        WD         Normal    181500
# 2   3          60       RL  ...        WD         Normal    223500
# 3   4          70       RL  ...        WD        Abnorml    140000
# 4   5          60       RL  ...        WD         Normal    250000
#
# [5 rows x 81 columns]

# %%
housing_data.shape
# Out:
# (1460, 81)

# %%
housing_data.describe(include="all")
# Out:
#                  Id   MSSubClass  ... SaleCondition      SalePrice
# count   1460.000000  1460.000000  ...          1460    1460.000000
# unique          NaN          NaN  ...             6            NaN
# top             NaN          NaN  ...        Normal            NaN
# freq            NaN          NaN  ...          1198            NaN
# mean     730.500000    56.897260  ...           NaN  180921.195890
# std      421.610009    42.300571  ...           NaN   79442.502883
# min        1.000000    20.000000  ...           NaN   34900.000000
# 25%      365.750000    20.000000  ...           NaN  129975.000000
# 50%      730.500000    50.000000  ...           NaN  163000.000000
# 75%     1095.250000    70.000000  ...           NaN  214000.000000
# max     1460.000000   190.000000  ...           NaN  755000.000000
#
# [11 rows x 81 columns]

# %%
housing_data.isnull().sum()
# Out:
# Id                 0
# MSSubClass         0
# MSZoning           0
# LotFrontage      259
# LotArea            0
#                 ...
# MoSold             0
# YrSold             0
# SaleType           0
# SaleCondition      0
# SalePrice          0
# Length: 81, dtype: int64

# %%
housing_data.dropna(axis=1,inplace=True)

# %%
housing_data.shape
# Out:
# (1460, 62)

# %%
housing_data.drop(columns=['Id'],axis=1, inplace=True)
if 'Id' not in housing_data: print("Id removed")
# Out:
# Id removed

# %%
y=housing_data['SalePrice']
sns.displot(data=housing_data, x='SalePrice')

# %%
x=housing_data['TotRmsAbvGrd']
plt.scatter(x,y)

# %%
sns.boxenplot(x,y)
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %%
#drop columns that contain NaN 
X = housing_data.drop(columns = ['SalePrice'], axis = 1, )
X_no_null = X.dropna(axis = 1)
df=X_no_null
df.shape
# Out:
# (1460, 60)

# %%
df["KitchenQual"].value_counts()
# Out:
# TA    735
# Gd    586
# Ex    100
# Fa     39
# Name: KitchenQual, dtype: int64

# %%
dummy_variable_1 = pd.get_dummies(df["KitchenQual"]) 
dummy_variable_1.head() 
df = pd.concat([df, dummy_variable_1], axis=1) 
df.head()
# Out:
#    MSSubClass MSZoning  LotArea Street LotShape  ... SaleCondition Ex Fa Gd TA
# 0          60       RL     8450   Pave      Reg  ...        Normal  0  0  1  0
# 1          20       RL     9600   Pave      Reg  ...        Normal  0  0  0  1
# 2          60       RL    11250   Pave      IR1  ...        Normal  0  0  1  0
# 3          70       RL     9550   Pave      IR1  ...       Abnorml  0  0  1  0
# 4          60       RL    14260   Pave      IR1  ...        Normal  0  0  1  0
#
# [5 rows x 64 columns]

# %%
df['Neighborhood'].value_counts()
# Out:
# NAmes      225
# CollgCr    150
# OldTown    113
# Edwards    100
# Somerst     86
# Gilbert     79
# NridgHt     77
# Sawyer      74
# NWAmes      73
# SawyerW     59
# BrkSide     58
# Crawfor     51
# Mitchel     49
# NoRidge     41
# Timber      38
# IDOTRR      37
# ClearCr     28
# SWISU       25
# StoneBr     25
# MeadowV     17
# Blmngtn     17
# BrDale      16
# Veenker     11
# NPkVill      9
# Blueste      2
# Name: Neighborhood, dtype: int64

# %%
df.Neighborhood
# Out:
# 0       CollgCr
# 1       Veenker
# 2       CollgCr
# 3       Crawfor
# 4       NoRidge
#          ...
# 1455    Gilbert
# 1456     NWAmes
# 1457    Crawfor
# 1458      NAmes
# 1459    Edwards
# Name: Neighborhood, Length: 1460, dtype: object

# %%
top_neighborhoods = ['NAmes','CollgCr', 'OldTown', 'Edwards']
not_top_neigh = ~df['Neighborhood'].isin(top_neighborhoods)
df['Neighborhood'].isin(top_neighborhoods)
not_top_neigh
df['Neighborhood'].loc[not_top_neigh] = 'Other'
df.Neighborhood
# Out:
# /usr/local/lib/python3.7/dist-packages/pandas/core/indexing.py:670: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   iloc._setitem_with_indexer(indexer, value)
# 0       CollgCr
# 1         Other
# 2       CollgCr
# 3         Other
# 4         Other
#          ...
# 1455      Other
# 1456      Other
# 1457      Other
# 1458      NAmes
# 1459    Edwards
# Name: Neighborhood, Length: 1460, dtype: object

# %%
dummy_variable_2 = pd.get_dummies(df["Neighborhood"]) 

df = pd.concat([df, dummy_variable_2], axis=1) 
df.head()
# Out:
#    MSSubClass MSZoning  LotArea Street  ... Edwards NAmes OldTown Other
# 0          60       RL     8450   Pave  ...       0     0       0     0
# 1          20       RL     9600   Pave  ...       0     0       0     1
# 2          60       RL    11250   Pave  ...       0     0       0     0
# 3          70       RL     9550   Pave  ...       0     0       0     1
# 4          60       RL    14260   Pave  ...       0     0       0     1
#
# [5 rows x 69 columns]

# %%
sns.scatterplot(y='SalePrice', x='Neighborhood', data=housing_data)

# %%
sns.lmplot(y='SalePrice', x='LotArea', data=housing_data)

# %%
#drop object columns 
X_num = df[df.T[df.dtypes!=np.object].index]
df=X_num
df
# Out:
#       MSSubClass  LotArea  OverallQual  ...  NAmes  OldTown  Other
# 0             60     8450            7  ...      0        0      0
# 1             20     9600            6  ...      0        0      1
# 2             60    11250            7  ...      0        0      0
# 3             70     9550            7  ...      0        0      1
# 4             60    14260            8  ...      0        0      1
# ...          ...      ...          ...  ...    ...      ...    ...
# 1455          60     7917            6  ...      0        0      1
# 1456          20    13175            6  ...      0        0      1
# 1457          70     9042            7  ...      0        0      1
# 1458          20     9717            5  ...      1        0      0
# 1459          20     9937            5  ...      0        0      0
#
# [1460 rows x 42 columns]

# %%
y = housing_data['SalePrice']
y
# Out:
# 0       208500
# 1       181500
# 2       223500
# 3       140000
# 4       250000
#          ...
# 1455    175000
# 1456    210000
# 1457    266500
# 1458    142125
# 1459    147500
# Name: SalePrice, Length: 1460, dtype: int64

# %%
#X = df[['GrLivArea','LotArea', 'BedroomAbvGr', 'OverallQual', 'OverallCond','YearBuilt','YearRemodAdd','BedroomAbvGr','TotRmsAbvGrd','GarageArea','FullBath','MoSold','TotalBsmtSF','Ex','Fa','Gd','TA']]
df.head()
X=df

# %%
X = sm.add_constant(X)
X.head()
# Out:
#    const  MSSubClass  LotArea  OverallQual  ...  Edwards  NAmes  OldTown  Other
# 0    1.0          60     8450            7  ...        0      0        0      0
# 1    1.0          20     9600            6  ...        0      0        0      1
# 2    1.0          60    11250            7  ...        0      0        0      0
# 3    1.0          70     9550            7  ...        0      0        0      1
# 4    1.0          60    14260            8  ...        0      0        0      1
#
# [5 rows x 43 columns]

# %%
model = sm.OLS(y, X)
results = model.fit()
print(results.summary())
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:              SalePrice   R-squared:                       0.830
# Model:                            OLS   Adj. R-squared:                  0.825
# Method:                 Least Squares   F-statistic:                     182.5
# Date:                Thu, 22 Apr 2021   Prob (F-statistic):               0.00
# Time:                        18:26:25   Log-Likelihood:                -17251.
# No. Observations:                1460   AIC:                         3.458e+04
# Df Residuals:                    1421   BIC:                         3.479e+04
# Df Model:                          38
# Covariance Type:            nonrobust
# ...
#                     coef    std err          t      P>|t|      [0.025      0.975]
# ---------------------------------------------------------------------------------
# const          7.804e+05   9.32e+05      0.837      0.403   -1.05e+06    2.61e+06
# ...

# %%
# Have fun!!

# %%
# %%html
# <img src='https://sd.keepcalms.com/i/keep-calm-and-have-fun-explore.png' />
# Out:
# <img src='https://sd.keepcalms.com/i/keep-calm-and-have-fun-explore.png' />
