# %% [markdown]
# <a href="https://colab.research.google.com/github/clairewangqc/ml_projects/blob/main/hotel_recommender.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.metrics.pairwise import cosine_similarity
import pandas as pd

# %%
data = pd.read_csv('https://raw.githubusercontent.com/cjflanagan/cs68/master/Datafiniti_Hotel_Reviews%20-%20Datafiniti_Hotel_Reviews.csv')

# %%
data.head()
# Out:
#                      id  ...                                           websites
# 0  AVwc252WIN2L1WUfpqLP  ...                      http://www.ranchovalencia.com
# 1  AVwc252WIN2L1WUfpqLP  ...                      http://www.ranchovalencia.com
# 2  AVwc252WIN2L1WUfpqLP  ...                      http://www.ranchovalencia.com
# 3  AVwdOclqIN2L1WUfti38  ...  http://www.starwoodhotels.com/alofthotels/prop...
# 4  AVwdOclqIN2L1WUfti38  ...  http://www.starwoodhotels.com/alofthotels/prop...
#
# [5 rows x 25 columns]

# %%
data['reviews.text']
# Out:
# 0       Our experience at Rancho Valencia was absolute...
# 1       Amazing place. Everyone was extremely warm and...
# 2       We booked a 3 night stay at Rancho Valencia to...
# 3       Currently in bed writing this for the past hr ...
# 4       I live in Md and the Aloft is my Home away fro...
#                               ...
# 3964                           Nice hotel/ great location
# 3965    very nice stay.. will be back to another location
# 3966    Only stayed one night but that was enough to e...
# 3967    I have been staying at the Four Points Sherato...
# 3968    Thank you Erik for taking care of my friends a...
# Name: reviews.text, Length: 3969, dtype: object

# %% [markdown]
# ## **Examing the dataset**

# %%
data.shape #(3969, 25) 
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3969 entries, 0 to 3968
# Data columns (total 25 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   id                    3969 non-null   object
#  1   dateAdded             3969 non-null   object
#  2   dateUpdated           3969 non-null   object
#  3   address               3969 non-null   object
#  4   categories            3969 non-null   object
#  5   primaryCategories     3969 non-null   object
#  6   city                  3969 non-null   object
#  7   country               3969 non-null   object
#  8   keys                  3969 non-null   object
#  9   latitude              3969 non-null   float64
#  10  longitude             3969 non-null   float64
#  11  name                  3969 non-null   object
#  12  postalCode            3969 non-null   object
#  13  province              3969 non-null   object
#  14  reviews.date          3969 non-null   object
#  15  reviews.dateSeen      3969 non-null   object
#  16  reviews.rating        3969 non-null   float64
#  17  reviews.sourceURLs    3969 non-null   object
#  18  reviews.text          3969 non-null   object
#  19  reviews.title         3968 non-null   object
#  20  reviews.userCity      1392 non-null   object
#  21  reviews.userProvince  934 non-null    object
#  22  reviews.username      3969 non-null   object
#  23  sourceURLs            3969 non-null   object
#  24  websites              3969 non-null   object
# dtypes: float64(3), object(22)
# memory usage: 775.3+ KB

# %%
data['reviews.text'].head(10)
# Out:
# 0    Our experience at Rancho Valencia was absolute...
# 1    Amazing place. Everyone was extremely warm and...
# 2    We booked a 3 night stay at Rancho Valencia to...
# 3    Currently in bed writing this for the past hr ...
# 4    I live in Md and the Aloft is my Home away fro...
# 5    I stayed here with my family for my daughters ...
# 6    Beautiful rooms and the nicest people working ...
# 7    We stayed here while visiting Maryland Live!. ...
# 8    I travel a lot with my job, so I'm constantly ...
# 9    In my line of work, I use meeting space in hot...
# Name: reviews.text, dtype: object

# %%
#Print overviews of the first 10 reviews_text. 
for i in range(10): 
  print(data['reviews.text'].iloc[i])
# Out:
# Our experience at Rancho Valencia was absolutely perfect from beginning to end!!!! We felt special and very happy during our stayed. I would come back in a heart beat!!!
# Amazing place. Everyone was extremely warm and welcoming. We've stayed at some top notch places and this is definitely in our top 2. Great for a romantic getaway or take the kids along as we did. Had a couple stuffed animals waiting for our girls upon arrival. Can't wait to go back.
# We booked a 3 night stay at Rancho Valencia to play some tennis, since it is one of the highest rated tennis resorts in America. This place is really over the top from a luxury standpoint and overall experience. The villas are really perfect, the staff is great, attention to details (includes fresh squeezed orange juice each morning), restaurants, bar and room service amazing, and the tennis program was really impressive as well. We will want to come back here again.
# Currently in bed writing this for the past hr 1/2 there have been dogs barking and squealing call the front desk to advise basically to be told there's nothing they can do. 315.00 and I can't sleep.
# I live in Md and the Aloft is my Home away from home...we stayed 1 night 7-7-16 ...Staff is great ! Especially Olivia who was Extra special because she remembered me by my voice over the phone ...which tells me she is very alert and pays attention to the customer their needs.AND SHE DID ! Thumbs up... More
# I stayed here with my family for my daughters wedding. It had a very accommodating staff, Olivia was excellent. The rooms were very well maintained. Would highly recommend this hotel, especially if your wedding venue is Celebrations at the Bay!
# Beautiful rooms and the nicest people working there. The front desk lady, Olivia, was extremely patient and helpful. We had lots of questions and she had just as many answers. The rooms were sleek and modern. The only thing that would make this hotel better would be free breakfast, but I really am asking for a lot. A++ stay. Thank... More
# We stayed here while visiting Maryland Live!. Cute hotel in a great location. Clean, with a very modern look, upgraded bathrooms and amenities and super nice staff. Would definitely recommend and stay there again!
# I travel a lot with my job, so I'm constantly staying at hotels. When my co-workers and I arrived late last night at the Aloft the people at the front desk were more than welcoming. When I wanted to order room service I was told it was too late however, Olivia at the front desk informed me of a Italian... More
# In my line of work, I use meeting space in hotels often. In my 15+ years of doing this work, this is the first time I've felt the undeniable pull to go out and write a hotel review, based solely on my meeting room experience. Though I did not use a guest room here, my colleagues who did shared that... More

# %%
#There are 307 different cities in the dataset. 
cities = data['city'].unique()
print(f'There are {len(cities)} different cities in the dataset. ')
print("")
print(cities)
# Out:
# There are 307 different cities in the dataset.
#
# ['Rancho Santa Fe' 'Hanover' 'Vancouver' 'Kansas City' 'Huntingdon'
#  'Perry' 'San Francisco' 'Vineland' 'Oxon Hill' 'San Diego' 'Des Plaines'
#  'Kissimmee' 'Chicago' 'Boston' 'New Orleans' 'Las Vegas' 'Miami Beach'
#  'New York' 'Honolulu' 'Miami' 'Los Angeles' 'Beverly Hills' 'Coronado'
#  'Philadelphia' 'Napa' 'Dallas' 'Key West' 'Seattle' 'Phoenix' 'Atlanta'
#  'Anaheim' 'Atlantic City' 'La Jolla' 'Orlando' 'Concord' 'Shelbyville'
#  'Woodbridge' 'Durham' 'Orange' 'Colorado Springs' 'Hawthorne' 'Henderson'
#  'Fort Worth' 'San Antonio' 'Danville' 'Sedona' 'Acworth' 'Dodge City'
#  'Baton Rouge' 'Flagstaff' 'New Castle' 'Cherokee' "Coeur d'Alene"
#  'Middletown' 'Frisco' 'Arkansas City' 'Winfield' 'Dover' 'Gardner'
#  'Ankeny' 'Brighton' 'Hilo' 'North Las Vegas' 'Alpharetta' 'East Tawas'
#  'Northwood' 'Bloomingdale' 'Portland' 'Rockford' 'Austin'
#  'Rancho Cucamonga' 'Auburn' 'Biddeford' 'Granbury' 'Williamsburg'
#  'Aurora' 'Pico Rivera' 'Rosemead' 'El Segundo' 'Dublin' 'Sausalito'
#  'Indianapolis' 'Brookings' 'Pasadena' 'San Luis Obispo' 'Palm Springs'
#  'Lake Forest' 'Valencia' 'Buena Park' 'Barstow' 'Morro Bay' 'Cleveland'
#  'Ashburn' 'Lithonia' 'Columbus' 'Clermont' 'Hollywood' 'Brooksville'
#  'Hialeah' 'Jacksonville' 'Clearwater' 'Bradenton' 'Daytona Beach'
#  'Cocoa Beach' 'Clearwater Beach' 'Cape Coral' 'Lake Placid'
#  'Old Orchard Beach' 'Saco' 'Russell' 'Waldorf' 'Cedar Rapids' 'Altoona'
#  'Charlotte' 'Calistoga' 'Fairbanks' 'Anchorage' 'Bentonville' 'Kingman'
#  'Clarksville' 'Athens' 'Gatlinburg' 'Beckley' 'Jane Lew' 'Coshocton'
#  'Elkhorn' 'Fond du Lac' 'Appleton' 'Bend' 'Janesville' 'Grants Pass'
#  'Chantilly' 'El Paso' 'Springfield' 'Tualatin' 'Forest Grove' 'Corvallis'
#  'Corsicana' 'Corpus Christi' 'Grand Prairie' 'Amarillo' 'Panhandle'
#  'Elkton' 'Morrisville' 'Abingdon' 'Bethlehem' 'Erie' 'Carlisle'
#  'Clearfield' 'King of Prussia' 'Markleysburg' 'Montgomeryville'
#  'West Chester' 'Bradford' 'Washington' 'Benton' 'Allentown' 'North Wales'
#  'Milwaukee' 'Elkhart' 'East Dover' 'Elgin' 'Westbury' 'Mattituck' 'Tomah'
#  'Santa Fe' 'Asheboro' 'Bowling Green' 'Harker Heights' 'Florence'
#  'Greenville' 'Fenton' 'Butte' 'Chalmette' 'Kenyon' 'Lancaster'
#  'Monticello' 'Albert Lea' 'Peoria' 'DeKalb' 'Collinsville' 'Woodstock'
#  'Bolingbrook' 'Cary' 'Schiller Park' 'Franklin' 'Bettendorf'
#  'Bainbridge Island' 'Walla Walla' 'Heyburn' 'Bear' 'Pensacola' 'Cortez'
#  'Orange City' 'DeLand' 'Fort Walton Beach' 'Homosassa' 'Brandon'
#  'Palm Beach' 'Mulberry' 'Avon Park' 'Guilford' 'Cañon City' 'Fullerton'
#  'Fontana' 'Eureka' 'El Centro' 'Culver City' 'Rialto' 'Long Beach'
#  'Berkeley' 'Atascadero' 'Pismo Beach' 'Monterey Park' 'Monrovia'
#  'Glendale' 'Huntington Beach' 'Scottsdale' 'Saint Louis' 'Palestine'
#  'Sutter Creek' 'Corrales' 'Park City' 'Elko' 'Cambridge' 'Madison'
#  'Gloucester' 'Brookline' 'Peabody' 'Littleton' 'Beverly'
#  'West Springfield' 'Everett' 'Aiken' 'Delavan' 'Baraboo' 'Arlington'
#  'Omaha' 'Hackettstown' 'Rahway' 'New Providence' 'Medina' 'Somerset'
#  'Broken Arrow' 'Elk City' 'Broken Bow' 'Dunn' 'Chimney Rock' 'Asheville'
#  'Newaygo' 'Cassville' 'Summerville' 'Marietta' 'Rolla' 'Norcross'
#  'Independence' 'Sacramento' 'Newport News' 'Deming' 'Clinton' 'Dayton'
#  'Brooklyn' 'Fayetteville' 'Corbin' 'Louisville' 'Medford' 'Solvang'
#  'Newburyport' 'Houston' 'Silver Spring' 'Glenview' 'Glen Burnie'
#  'Gladstone' 'Reynoldsburg' 'Linthicum Heights' 'Farmington' 'Los Alamos'
#  'Marina' 'Davenport' 'New Philadelphia' 'Hampton' 'Chincoteague Island'
#  'Myrtle Beach' 'Southfield' 'Tyler' 'Edgartown' 'Lahaina'
#  'Virginia Beach' 'Lincoln' 'Baltimore' 'Sarasota' 'Byron Center'
#  'Grand Rapids' 'Warner Robins' 'Lockport' 'Carmel Valley' 'Benton Harbor'
#  'Cape May' 'Golden' 'Raynham' 'Winchester' 'Desert Hot Springs' 'Oshkosh'
#  'Richardson' 'Union City' 'Plainview' 'Longboat Key']

# %%
#There are 462 different hotels in the dataset. 
hotels = data['name'].unique()
print(f'There are {len(hotels)} different hotels in the dataset. ')
print("")
print(hotels)
# Out:
# There are 462 different hotels in the dataset.
#
# ['Rancho Valencia Resort Spa' 'Aloft Arundel Mills'
#  'Hampton Inn Suites PortlandVancouver' 'Hotel Phillips'
#  'The Inn at Solvang' 'Econolodge' 'Hotel Zelos' 'EconoLodge'
#  'Hampton Inn Suites National HarborAlexandria Area'
#  'Fairmont Grand Del Mar' 'Best Western at OHare'
#  'Clarion Resort Waterpark' 'Virgin Hotels Chicago' 'The Boxer'
#  'The Old No. 77 Hotel & Chandlery'
#  'Main Street Station Casino Brewery Hotel' 'Fremont Hotel & Casino'
#  'The Charlesmark Hotel' 'AC Hotel by Marriott Boston Downtown'
#  'The Hotel of South Beach' 'The Pearl Hotel' 'Hotel Renew'
#  'Four Seasons Hotel New York Downtown' 'The James New York – NoMad'
#  'MOXY New Orleans Downtown/French Quarter Area' 'Bienville House'
#  'Room Mate Lord Balfour' 'The Westin Las Vegas Hotel & Spa' 'The Broome'
#  'W Boston' 'Mandarin Oriental, Miami' 'The Ritz-Carlton, Boston'
#  'The St. Regis New York' 'Miyako Hotel Los Angeles'
#  'AC Hotel Chicago Downtown' 'Ace Hotel Chicago' 'dana hotel and spa'
#  'Kinzie Hotel' 'Moxy Chicago Downtown' 'Montage Beverly Hills'
#  'Hotel Zetta San Francisco' '1906 Lodge At Coronado Beach'
#  'Home2 Suites By Hilton Philadelphia-Convention Center, Pa'
#  'Chelsea Savoy Hotel' 'Central Loop Hotel' 'Royal Resort'
#  'Sterling Gardens Hotel' 'SpringHill Suites Las Vegas Convention Center'
#  'The Cartwright Hotel - Union Square, BW Premier Collection'
#  'Best Western Plus Inn At The Vines' 'Aloft New Orleans Downtown'
#  'Hampton Inn and Suites Napa'
#  'Hampton Inn & Suites Dallas/Cockrell Hill I-30'
#  'Fairfield Inn & Suites by Marriott Key West at The Keys Collection'
#  'The Villa Toscana' 'Bed and Breakfast Inn Seattle'
#  'Quality Inn Midway Airport' 'Rodeway Inn' 'Freehand Chicago'
#  'WoodSpring Suites Phoenix I-10 West' 'Holiday Inn North Phoenix'
#  'Comfort Inn I-10 West at 51st Ave'
#  'Red Roof Inn Phoenix North - Bell Road' 'Hotel 502' 'The Nolitan Hotel'
#  'Hilton Garden Inn Atlanta Downtown' 'The Beekman, A Thompson Hotel'
#  'The St. Regis Atlanta'
#  'Extended Stay America - Atlanta - Perimeter - Hammond Drive'
#  'Quality Inn & Suites' 'Central Park West Hostel'
#  'Hampton Inn Atlanta-Perimeter Center'
#  'Extended Stay America - Atlanta - Clairmont' 'The Redbury New York'
#  'Silver Cloud Inn - Seattle Lake Union'
#  'Residence Inn Seattle Downtown/Lake Union' 'Inn at El Gaucho'
#  'La Quinta Inn & Suites Phoenix I-10 West'
#  'Residence Inn Phoenix North/Happy Valley'
#  'Courtyard Phoenix North/Happy Valley' 'The Carlyle, A Rosewood Hotel'
#  'DoubleTree by Hilton Hotel Metropolitan - New York City'
#  'The Westin Chicago River North' 'FOUND:RE Phoenix'
#  'TownePlace Suites Anaheim Maingate Near Angel Stadium'
#  'Maison de Macarty' 'Hotel Storyville' 'Econo Lodge'
#  'Ace Hotel New Orleans' 'XV Beacon' 'Bricco Suites'
#  'Beacon Hill Hotel and Bistro'
#  'Embassy Suites by Hilton Boston at Logan Airport'
#  'The College Club of Boston'
#  'The Roosevelt New Orleans, A Waldorf Astoria Hotel' 'Cornstalk Hotel'
#  'French Quarter Suites Hotel' 'Soniat House' 'The Pontchartrain Hotel'
#  'Martinique Motel' 'The Annex at The Chelsea' 'Eden Roc Inn & Suites'
#  'Best Western Courtesy Inn' 'Park Vue Inn'
#  'Holiday Inn Anaheim-Resort Area' 'Pacific Inn'
#  'Quality Inn & Suites Anaheim Maingate' 'Best Western Envoy Inn'
#  'Best Western Seven Seas'
#  'Embassy Suites by Hilton Philadelphia - Center City'
#  'Rodeway Inn San Diego Near Qualcomm Stadium'
#  'Holiday Inn Express San Diego Sea World - Beach Area'
#  'Grande Colonial La Jolla' 'Residence Inn San Diego Central'
#  'SpringHill Suites San Diego Rancho Bernardo/Scripps Poway'
#  'Fairfield Inn Philadelphia Airport'
#  'Hyatt Regency Orlando International Airport' 'Hilton Garden Inn Napa'
#  'NOPSI Hotel New Orleans'
#  'The Troubadour Hotel New Orleans, Tapestry Collection by Hilton'
#  'Courtyard Seattle Downtown/Lake Union' 'Hyatt House Seattle/Downtown'
#  'Aloft Philadelphia Downtown'
#  'The Saint Hotel Key West, Autograph Collection'
#  'Suncoast Hotel and Casino' 'Rodeway Inn Oceanview'
#  'Rodeway Inn Boardwalk' 'River Hotel'
#  'Wyndham Canterbury at San Francisco' 'Motel 6 Atlanta Downtown'
#  'Drury Inn & Suites Atlanta Airport' 'Halcyon Hotel' 'Comfort Inn'
#  'Clarion Inn & Suites' 'Hotel St. Augustine' 'Hotel Royal'
#  'Bay Pointe Inn Restaurant' 'Hampton Inn Potomac Mills/Woodbridge'
#  'Quality Inn Suites Medical Park' 'Best Western Orange Plaza'
#  'The Academy Hotel Colorado Springs' 'Ramada Plaza Hawthorne/LAX'
#  'Economy Inn Suites' 'Holiday Inn Express Suites Fort Worth Downtown'
#  'La Quinta Inn Suites San Antonio Northwest' 'Pine Barn Inn'
#  'Wildflower Inn' 'Hampton Inn & Suites Dodge City'
#  'Holiday Inn Express & Suites Baton Rouge East'
#  'Arizona Mountain Inn & Cabins' 'Hollywood Motel' 'Stonebrook Lodge'
#  "Hampton Inn & Suites Coeur d'Alene"
#  'Hampton Inn & Suites Newport/Middletown' 'Snowshoe Motel'
#  'Americas Best Value Inn-arkansas City' 'Liberty Inn' 'Dover Inn'
#  'The Colonial Hotel' 'Ramada-ankeny'
#  'Holiday Inn Express & Suites Denver Northeast - Brighton'
#  'Comfort Suites-dodge City' 'Pakalana Inn'
#  'The Westin San Diego Gaslamp Quarter'
#  'Hampton Inn Las Vegas North Speedway'
#  'Courtyard Las Vegas Henderson/Green Valley'
#  'Loews Portofino Bay Hotel at Universal Orlando'
#  'Hyatt Regency Grand Cypress' 'Holiday Inn Express Alpharetta - Roswell'
#  'Tawas Bay Beach Resort' 'Holiday Inn Express Suites Northwood'
#  'Residence Inn Chicago Bloomingdale'
#  'The Press Hotel, Autograph Collection' 'ARIA Resort Casino'
#  'Staybridge Suites Rockford' 'W Austin'
#  'Best Western Plus Heritage Inn Rancho Cucamonga/Ontario' 'Hotel Lincoln'
#  'Auburn Travelodge Inn & Suites' 'Biddeford Motel'
#  'Best Western Granbury Inn Suites' 'Omni Royal Orleans'
#  'Hilton Garden Inn Williamsburg' 'The Bertram Inn & Conference Center'
#  'Flamingo Inn Rosemead' 'Travelodge-lax South'
#  'Cloverleaf Residence Suites' 'The Gables Inn Sausalito'
#  'Drury Plaza Hotel Indianapolis Carmel' 'Ocean Suites'
#  'The Saga Motor Hotel' 'La Cuesta Inn' 'Inn At San Luis Obispo'
#  'Desert Lodge' 'Candlewood Suites Orange County/Irvine East'
#  'Hyatt Regency-valencia' 'Motel 6' 'Nites Inn' 'Pacific Shores Inn'
#  'Aloft Cleveland Downtown' 'Best Western-ashburn Inn'
#  'Holiday Inn Express & Suites Atlanta East - Lithonia'
#  'Holiday Inn Express & Suites Columbus Univ Area - Osu'
#  'Holiday Inn Express & Suites Columbus - Polaris Parkway'
#  'Innkeeper Danville West' 'Holiday Inn Express Clermont'
#  'Bougainvillea On The Beach' 'Quality Inn' 'Ramada Hialeah Miami Airport'
#  'Aloft Jacksonville Tapestry Park' 'Orange Motel'
#  'Hampton Inn & Suites Bradenton Downtown Historic District'
#  'Cozy Villa Motel' 'Sea-Aire Motel' 'Echo Sails Motel'
#  'Dolphin Key Resort' 'Best Western Pasadena Royale'
#  'Holiday Inn Express & Suites Lake Placid' 'Imperial Waters'
#  'Elmwood Motor Court' 'Island View Motel' 'Hampton Inn-saco/biddeford'
#  'The Lodge At Russell' 'Residence Inn By Marriott Waldorf'
#  'Hampton Inn & Suites Cedar Rapids North'
#  'Hampton Inn & Suites Altoona-des Moines'
#  'Drury Inn & Suites Charlotte Northlake'
#  'Best Western Plus Stevenson Manor' 'Super 8-dover'
#  'Coconut Waikiki Hotel' 'Golden North Motel' 'Aviator Hotel Anchorage'
#  'Simmons Suites' 'Ramada-kingman' 'Westgate Inn & Suites'
#  'Mainstay Suites-fort Campbell' 'Hampton Inn & Suites Brookings'
#  'Hampton Inn-athens' 'Chalet Inn' 'Travelodge-beckley'
#  'Plantation Inn & Suites' 'Roscoe Motor Inn' 'Hampton Inn-elkhorn'
#  'Holiday Inn Express & Suites Fond Du Lac' 'Copperleaf Hotel'
#  'Best Western Appleton Inn' 'Hampton Inn & Suites Bend' 'Chalet Motel'
#  'Hampton Inn-janesville' 'Riverside Inn' 'Motel Del Rogue'
#  'Staybridge Suites Chantilly Dulles Airport'
#  'Staybridge Suites El Paso Airport Area'
#  'Holiday Inn Express Washington Dc Sw - Springfield' 'Century Hotel'
#  'Best Western University Inn & Suites' 'University Inn Corvallis'
#  'La Quinta Inn & Suites Corsicana'
#  'Americas Best Value Inn-corpus Christi North/airport'
#  'La Quinta Inn & Suites Dallas Grand Prairie South'
#  'Holiday Inn Express & Suites Amarillo West' 'Budget Inn'
#  'Quality Inn & Suites Nj State Capital Area' 'Alpine Motel'
#  'Historic Hotel Bethlehem' 'Avalon Hotel & Conference Center'
#  'Pike Motel' 'Best Western Plus Clearfield' 'Radisson Hotel Valley Forge'
#  'National Trail Motel' 'Hotel Warner' 'Heritage Suites'
#  "America's Best Value Inn" 'Central Park Hotel'
#  'Comfort Inn-lehigh Valley West'
#  'Hampton Inn & Suites Philadelphia Montgomeryville'
#  'Days Inn & Suites Milwaukee Airport' 'Fairway Inn' 'Cooper Hill Inn'
#  'Comfort Suites-elgin' 'Red Roof Plus+ Long Island-garden City'
#  'Mattituck Motel' 'Best Western Tomah Hotel'
#  'Residence Inn Springfield South' 'The Pecos Trail Inn'
#  'Baymont Inn & Suites Bowling Green' 'Best Western Harker Heights'
#  'Holiday Inn Express & Suites Florence I-95 & I-20 Civic Ctr'
#  'Aloft Greenville Downtown' 'Drury Inn & Suites St Louis Fenton'
#  'Holiday Inn Express & Suites Butte' 'La Quinta Inn & Suites Butte'
#  'Best Western Plus Chalmette Hotel' "Schweich's Hotel Bar & Restaurant"
#  'Homewood Suites By Hilton Lancaster' 'Super 8 Monticello'
#  'Holiday Inn Express & Suites Austin South' 'Motel 6-albert Lea'
#  'Mark Twain Hotel' 'Red Roof Inn & Suites Dekalb'
#  'Drury Inn St Louis Collinsville' 'Best Western-woodstock Inn'
#  'Aloft Bolingbrook' 'Comfort Suites-regency Park'
#  "Four Points By Sheraton Chicago O'hare Airport" 'Alpine Inn'
#  'Drury Plaza Hotel Nashville Franklin'
#  'Hilton Garden Inn Bettendorf/quad Cities' 'Island Country Inn'
#  'BEST WESTERN PLUS Walla Walla Suites Inn' "Top's Motel"
#  'Best Western Plus Newark/christiana Inn' 'National 9 Inn-sand Canyon'
#  'Orange City Motel' 'Riviera Resort & Marina'
#  'Holiday Inn Resort Fort Walton Beach' "MacRae's Of Homosassa Inc"
#  'Chart House Suites On Clearwater Bay'
#  'Behind The Fence Bed & Breakfast Inn' 'Colony Hotel'
#  'Best Western Mulberry Hotel' 'Oak Tree Inn'
#  'Red Roof Plus+& Suites Guilford'
#  'Americas Best Value Inn & Suites Canon City' 'Grand Inn'
#  'Holiday Inn Express & Suites Eureka'
#  'Americas Best Value Inn & Suites-eureka' 'Super 8-el Centro'
#  'Westchester Hotel' 'Americas Best Value Inn-rialto' 'Hotel Sausalito'
#  'Best Western Inn At Palm Springs' 'Best Western-valencia Inn'
#  'Best Western Plus Hotel At The Convention Center' 'Bancroft Hotel'
#  'Rancho Tee Motel' 'Desert Inn Motel' 'Beach Comber Inn'
#  'Seacrest Oceanfront Hotel' 'Lincoln Plaza Hotel' 'Aztec Hotel'
#  'Chariot Inn' 'Pasea Hotel & Spa'
#  'Courtyard by Marriott Scottsdale Salt River'
#  'Hampton Inn & Suites St. Louis/South I-55'
#  'Hampton Inn & Suites Palestine' 'Hotel Sutter'
#  'The Chocolate Turtle Bed & Breakfast' 'The Varden Hotel'
#  'Hotel Del Flores' 'Park City Peaks Hotel' 'American Inn'
#  'The Charles Hotel' 'Hotel Red' 'Atlantis Oceanfront Inn' 'Longwood Inn'
#  'Plaza Motel' 'Lyttleton Inn' 'Beverly Garden Suites'
#  'Best Western Springfield West Inn' 'Hampton Inn-seattle/everett'
#  'Hotel Aiken' 'Super 8 Delavan Near Lake Geneva' 'Campus Inn Motel'
#  'Admiral Hotel' 'Staybridge Suites Omaha 80th And Dodge'
#  'Holiday Inn Express & Suites Bethlehem'
#  'Best Western Riverview Inn & Suites'
#  'Best Western Plus Murray Hill Hotel & Suites'
#  'Red Roof Inn Cleveland-medina' 'Candlewood Suites Somerset'
#  'Best Western Kenosha Inn' 'Motel 6 Jaiden & Jiya LLC'
#  'Beavers Bend Lodging' 'Seven Gables Inn' 'Aloft Durham Downtown'
#  'Carter Lodge' 'Comfort Suites Outlet Center' 'M -37 Motel'
#  'Schleichers Landing' 'Sleep inn'
#  'Microtel Inn Suites by Wyndham Marietta'
#  'Days Inn St. Louis - Lindbergh Boulevard' "America's Best Inn Suites"
#  'InterContinental San Francisco' 'Appletree Inn'
#  'Holiday Inn Express Baltimore-Bwi Airport West'
#  'Hyatt Regency Sacramento' 'Courtyard by Marriott Newport News Airport'
#  'Drury Inn Suites St. Louis Convention Center'
#  'Holiday Inn Express Suites Deming Mimbres Valley'
#  'Holiday Inn Express Suites Clinton' 'Drury Inn Suites Dayton North'
#  'Hotel Prince Spafford' 'Sleep Inn' 'Fairfield Inn Corbin'
#  'Howard Johnson Express Inn/Airport' 'Budget Inn of America'
#  'Solvang Inn Cottages' 'Garrison Inn' 'Portland Harbor Hotel'
#  'Courtyard by Marriott Houston Brookhollow'
#  'DoubleTree by Hilton Hotel Washington DC - Silver Spring'
#  'Best Western Plus Glenview-Chicagoland Inn Suites'
#  "SpringHill Suites Coeur d'Alene" 'Days Inn Baltimore South/Glen Burnie'
#  'Holiday Inn Express Portland Se - Clackamas Area' 'Circa 39 Hotel'
#  'Days Inn Columbus East' 'Hilton Garden Inn BWI Airport'
#  'Holiday Inn Express and Suites' 'Alamo Motel'
#  'Howard Johnson Marina at Monterey Bay'
#  'Hampton Inn Orlando-Maingate South' 'The L.A. Hotel Downtown'
#  'Best Western Dutch Valley Inn'
#  'Red Roof Inn Hampton Coliseum Convention Center' 'Comfort Suites'
#  'McMenamins Kennedy School' 'hampton inn Springfield southeast'
#  'Hilton Garden Inn Myrtle Beach/Coastal Grand Mall'
#  'Holiday Inn Express Suites Denver Sw-Littleton'
#  'Red Roof Inn Detroit - Southfield' 'Fairfield Inn Suites Tyler'
#  'Harborside Inn' 'Honua Kai Resort Spa'
#  'Virginia Beach Resort Hotel Conference Center'
#  'Hilton Baltimore BWI Airport' 'Staybridge Suites Lincoln Northeast'
#  'Hyatt Place Baltimore/Inner Harbor' 'Holiday Inn Sarasota-Airport'
#  'Baymont Inn Suites Grand Rapids SW/Byron Center'
#  'Hampton Inn and Suites Baltimore Inner Harbor'
#  'Hampton Inn and Suites Williamsburg-Central'
#  'Pier 5 Hotel Baltimore, Curio Collection by Hilton'
#  'Homewood Suites by Hilton Baltimore'
#  'SpringHill Suites by Marriott Virginia Beach Oceanfront'
#  'Sense Beach House' 'Home2 Suites by Hilton Baltimore Downtown'
#  'Sheraton Portland Airport Hotel'
#  'Fairfield Inn and Suites by Marriott Virginia Beach Oceanfront'
#  'Villa Paradiso' 'Motel 6 Grand Rapids - Airport'
#  'La Quinta Inn Suites Warner Robins - Robins AFB'
#  'Best Western Plus Lockport Hotel' 'Blue Sky Lodge' 'Hilton Garden Inn'
#  'Courtyard Austin South' 'The Star Inn'
#  'Hyatt Place Atlanta Airport-South' 'Table Mountain Inn'
#  'Sonesta ES Suites Flagstaff' 'Aqua Soleil Hotel And Mineral Water Spa'
#  'Best Western Plus Arroyo Roble Hotel & Creekside Villas' 'hotel le bleu'
#  'Residence Inn Dallas Richardson'
#  'Homewood Suites by Hilton Orlando-Nearest to Univ Studios'
#  'Tradewinds Restaurant' 'Hampton Inn Union City'
#  'Embassy Suites by Hilton Baltimore at BWI Airport'
#  'Four Points by Sheraton Plainview Long Island'
#  'The Resort at Longboat Key Club']

# %%
#Create new data frame to hold name, city and review text
groupByNameAndCity = data[['name', 'city', 'province', 'reviews.text']]

#Concatenate review texts for each group and create a new column all_reviews.  
groupByNameAndCity['all_reviews'] = groupByNameAndCity.groupby(['name', 'city'])['reviews.text'].transform(lambda review: ' '.join(review))

#Cleanup, drop old review column, then remove duplicates. 
groupByNameAndCity = groupByNameAndCity.drop(columns=['reviews.text'])
groupByNameAndCity = groupByNameAndCity.drop_duplicates()

#Preview, now we have one row per hote-city with all reviews in one field. 
groupByNameAndCity.head(20)
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """
#                                                   name  ...                                        all_reviews
# 0                           Rancho Valencia Resort Spa  ...  Our experience at Rancho Valencia was absolute...
# 3                                  Aloft Arundel Mills  ...  Currently in bed writing this for the past hr ...
# 9                 Hampton Inn Suites PortlandVancouver  ...  In my line of work, I use meeting space in hot...
# 15                                      Hotel Phillips  ...  Old hotel with many remaining architectural ch...
# 20                                  The Inn at Solvang  ...  Everything was sold out in State College for G...
# 21                                          Econolodge  ...  I work here in Perry about 6 days out of the w...
# 22                                         Hotel Zelos  ...  The hotel is just one of many that are on this...
# 26                                          EconoLodge  ...  After getting the bait and switch I decided I'...
# 28   Hampton Inn Suites National HarborAlexandria Area  ...  Hotel is in the perfect spot at the perfect pr...
# 59                              Fairmont Grand Del Mar  ...  We hosted our annual Client Event at The Grand...
# 75                               Best Western at OHare  ...  It's a great place to stay and leave a car if ...
# 79                            Clarion Resort Waterpark  ...  We Had the best time ever! r r What a ball we ...
# 80                               Virgin Hotels Chicago  ...  Awesome hotel. Virgin really took the time to ...
# 99                                           The Boxer  ...  Bad: Timing seemed to be off. Had to wait a ve...
# 149                   The Old No. 77 Hotel & Chandlery  ...  Loved this place! If you are looking for a cha...
# 154           Main Street Station Casino Brewery Hotel  ...  Bad: Better return from the slots!!. Good: Bed...
# 155                             Fremont Hotel & Casino  ...  Bad: Thumping music all night long. So loud th...
# 268                              The Charlesmark Hotel  ...  Bad: Had some trouble regulating the water tem...
# 367               AC Hotel by Marriott Boston Downtown  ...  Bad: Dont change a thing. Good: Staff was very...
# 368                           The Hotel of South Beach  ...  Bad: Pool close too early. Should be stay avai...
#
# [20 rows x 4 columns]

# %%
groupByNameAndCity.shape
# Out:
# (478, 4)

# %%
#Define a TF-IDF Vectorizer Object. Remove all english stop words such as 'the', 'a'
tfidf = TfidfVectorizer(stop_words='english')

#Construct the required TF-IDF matrix by fitting and transforming the reviews_text. 
tfidf_matrix = tfidf.fit_transform(groupByNameAndCity['all_reviews'])

#Output the shape of tfidf_matrix
tfidf_matrix.shape
# Out:
# (478, 10522)

# %%
cosine_sim = cosine_similarity(tfidf_matrix, tfidf_matrix) 
cosine_sim
# Out:
# array([[1.        , 0.05863792, 0.07082922, ..., 0.09441375, 0.04775548,
#         0.01903278],
#        [0.05863792, 1.        , 0.12855056, ..., 0.18870781, 0.10115468,
#         0.03092227],
#        [0.07082922, 0.12855056, 1.        , ..., 0.24625571, 0.15112957,
#         0.02266315],
#        ...,
#        [0.09441375, 0.18870781, 0.24625571, ..., 1.        , 0.17964553,
#         0.04426755],
#        [0.04775548, 0.10115468, 0.15112957, ..., 0.17964553, 1.        ,
#         0.01333912],
#        [0.01903278, 0.03092227, 0.02266315, ..., 0.04426755, 0.01333912,
#         1.        ]])

# %%
#Turn the cosine_sim matrix into a DataFrame.    
pd.DataFrame(cosine_sim, columns=groupByNameAndCity.name.values, index=groupByNameAndCity.name.values)
# Out:
#                                                    Rancho Valencia Resort Spa  ...  The Resort at Longboat Key Club
# Rancho Valencia Resort Spa                                           1.000000  ...                         0.019033
# Aloft Arundel Mills                                                  0.058638  ...                         0.030922
# Hampton Inn Suites PortlandVancouver                                 0.070829  ...                         0.022663
# Hotel Phillips                                                       0.037516  ...                         0.002584
# The Inn at Solvang                                                   0.045586  ...                         0.037502
# ...                                                                       ...  ...                              ...
# Tradewinds Restaurant                                                0.114275  ...                         0.029192
# Hampton Inn Union City                                               0.061830  ...                         0.031431
# Embassy Suites by Hilton Baltimore at BWI Airport                    0.094414  ...                         0.044268
# Four Points by Sheraton Plainview Long Island                        0.047755  ...                         0.013339
# The Resort at Longboat Key Club                                      0.019033  ...                         1.000000
#
# [478 rows x 478 columns]

# %%
#A list of hotel names and their associated index. 
indices = pd.Series(groupByNameAndCity.index, index=groupByNameAndCity['name']).drop_duplicates()
indices[0:10]
# Out:
# name
# Rancho Valencia Resort Spa                            0
# Aloft Arundel Mills                                   3
# Hampton Inn Suites PortlandVancouver                  9
# Hotel Phillips                                       15
# The Inn at Solvang                                   20
# Econolodge                                           21
# Hotel Zelos                                          22
# EconoLodge                                           26
# Hampton Inn Suites National HarborAlexandria Area    28
# Fairmont Grand Del Mar                               59
# dtype: int64

# %%
#I will pick "Rancho Valencia Resort Spa" and see what are the most similar hotels based on the review text. 
idx = indices['Rancho Valencia Resort Spa']
idx
# Out:
# 0

# %%
# Get the pairwise similarity scores of all hotels with that hotel. 
list(enumerate(cosine_sim[idx]))
sim_scores = list(enumerate(cosine_sim[idx]))
len(sim_scores)
# Out:
# 478

# %%
# Sort the hotels based on the similarity scores. 
sim_scores = sorted(sim_scores, key=lambda x: x[1], reverse=True) 
sim_scores[1:11]
# Out:
# [(168, 0.13169281011043593),
#  (356, 0.12409740776070381),
#  (95, 0.12213515092504901),
#  (197, 0.11942974982092452),
#  (182, 0.11623504655142164),
#  (473, 0.1142745361035582),
#  (21, 0.11152653452554154),
#  (12, 0.10765527764120346),
#  (9, 0.10746663499536074),
#  (385, 0.10652600977630781)]

# %%
# Get the scores of the 10 most similar hotels
sim_scores = sim_scores[1:11]
sim_scores
# Out:
# [(168, 0.13169281011043593),
#  (356, 0.12409740776070381),
#  (95, 0.12213515092504901),
#  (197, 0.11942974982092452),
#  (182, 0.11623504655142164),
#  (473, 0.1142745361035582),
#  (21, 0.11152653452554154),
#  (12, 0.10765527764120346),
#  (9, 0.10746663499536074),
#  (385, 0.10652600977630781)]

# %%
# Get the hotel indices.  
hotel_indices = []
for id, similarity in sim_scores: 
  hotel_indices.append(id) 

hotel_indices
# Out:
# [168, 356, 95, 197, 182, 473, 21, 12, 9, 385]

# %%
# Return the top 10 most similar hotels.  
top10_hotel_names = groupByNameAndCity[['name', 'city', 'province']].iloc[hotel_indices]
top10_hotel_names
# Out:
#                              name         city province
# 2115  Hyatt Regency Grand Cypress      Orlando       FL
# 2909             The Varden Hotel   Long Beach       CA
# 1516              Cornstalk Hotel  New Orleans       LA
# 2397       Hyatt Regency-valencia     Valencia       CA
# 2308           Omni Royal Orleans  New Orleans       LA
# 3921        Tradewinds Restaurant      Orlando       FL
# 376                   Hotel Renew     Honolulu       HI
# 80          Virgin Hotels Chicago      Chicago       IL
# 59         Fairmont Grand Del Mar    San Diego       CA
# 3011             Seven Gables Inn  Saint Louis       MO
